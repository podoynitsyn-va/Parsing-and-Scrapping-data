# %%
from bs4 import BeautifulSoup as bs
import requests
import re
import pandas as pd

# %%
def determine_salary(salary_string):
    '''
    На вход подаётся строка зарплаты вида:
    "от 10 до 50"
    "от 10"
    "до 50"
    "по договоренности"
    '''
    
    # salary =re.split(r'[^\d+\s+]+', salary_string)
    answer = {'salary_from': None, 'salary_to': None}

    # определим числа, которые содержатся в строке зарплаты
    salary = re.findall(r'[0-9\s]+', salary_string)
    # уберём html-неразрывный пробел между разрядами числа
    salary = [s.replace('\xa0', '') for s in salary]

    '''
    Если в salary 2 элемента, то в качестве начала и окончания вилки берем salary[0] и salary[1].
    Если в salary 1 элемент, то если строка salary_string начинается с 'от',
    то в качестве начала вилки используем salary[0].
    А если в строке salary_string присутствует слово 'до',
    то в качестве окончания вилки используем salary[0].
    Если же salary не содержит числовых элементов, то записываем None в начало и конец вилки
    '''
    if len(salary) == 2:
        answer['salary_from'] = int(salary[0])
        answer['salary_to'] = int(salary[1])
    elif salary_string.split()[0] == 'от':
        answer['salary_from'] = int(salary[0])
    elif salary_string.split().count('до') == 1:
        answer['salary_to'] = int(salary[0])

    return answer

# %%
def clear_link(link):
    link = link[:link.find('//')]+'//'+link[link.find('hh.ru'):link.find('?')]
    return link

# %%
def get_hh_data(keyword, link):
    link_origin = 'https://www.hh.ru'
    headers = {'Accept': '*/*',
               'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:68.0) Gecko/20100101 Firefox/68.0'}
    html = requests.get(link, headers=headers).text
    parsed_html = bs(html, 'html.parser')
    
    vacancy_list = parsed_html.findAll('div', {'data-qa': 'vacancy-serp__vacancy'})

    #определим ссылку на следующую страницу. Это ссылка на кнопку "Далее"
    next_link = link_origin + parsed_html.find('a',{'data-qa':'pager-next'})['href']
    
    #создадим списки с данными, которые будем использовать в качестве столбцов датафрейма
    list_vacancy_link = []
    list_vacancy_text = []
    list_vacancy_company = []
    list_vacancy_place = []
    list_salary_from = []
    list_salary_to = []

    for vacancy in vacancy_list:
        #подчистим ссылку на вакансию
        vacancy_link = clear_link(vacancy.find('a',{'class':'bloko-link'})['href'])
        
        vacancy_text = vacancy.find('a',{'class':'bloko-link'}).getText()
        vacancy_firm = vacancy.find('a', {'data-qa': 'vacancy-serp__vacancy-employer'}).getText()
        vacancy_place = vacancy.find('span', {'data-qa': 'vacancy-serp__vacancy-address'}).getText()
        try:
            salary_string = vacancy.find('div', {'class': 'vacancy-serp-item__compensation'}).text
            salary_dict = determine_salary(salary_string)
        except:
            salary_dict = {'salary_from':None, 'salary_to':None}
        
        #добавим полученные данные в списки
        list_vacancy_link.append(vacancy_link)
        list_vacancy_text.append(vacancy_text)
        list_vacancy_company.append(vacancy_firm)
        list_vacancy_place.append(vacancy_place)
        list_salary_from.append(salary_dict['salary_from'])
        list_salary_to.append(salary_dict['salary_to'])      
    
    #загрузим списки в датафрейм
    vacancy_info = pd.DataFrame({'vacancy_link':list_vacancy_link,
                             'vacancy_text':list_vacancy_text,
                             'vacancy_company':list_vacancy_company,
                             'vacancy_place':list_vacancy_place,
                             'salary_from':list_salary_from,
                             'salary_to':list_salary_to})
    return_data = {'data':vacancy_info, 'next_link':next_link}
    return return_data

# %%
keyword = input('Введите ключевое слово, по которому будет выполняться поиск подходящих вакансий:  ')
n_pages = int(input('Введите количество страниц поиска:  '))

#основной датафрейм vacancy_list - к нему будем присоединять результаты обхода страниц
vacancy_list = pd.DataFrame({'vacancy_link':[],
                             'vacancy_text':[],
                             'vacancy_company':[],
                             'vacancy_place':[],
                             'salary_from':[],
                             'salary_to':[]})
#ссылка на первую страницу
#Пришлось использовать параметр geo для обхода автоподстановки местоположения
link_hh = link = f'https://hh.ru/search/vacancy?area=1&st=searchVacancy&text={keyword}'
page = 1
while page <= n_pages:
    
    
    data = get_hh_data(keyword, link_hh)
    vacancy_info = data['data']
    
    #на следующем шаге цикла вместо первоначальной ссылки используем ссылку на следующую страницу
    link_hh = data['next_link']
    
    #добавляем полученные данные к vacancy_list
    vacancy_list = pd.concat([vacancy_list,vacancy_info], axis=0, ignore_index=True)
    page +=1
    
vacancy_list['website'] = 'www.hh.ru'

vacancy_list
# Out:
# Введите ключевое слово, по которому будет выполняться поиск подходящих вакансий:  Программист
# Введите количество страниц поиска:  5
#                       vacancy_link  \
# 0   https://hh.ru/vacancy/33814598
# 1   https://hh.ru/vacancy/33940776
# 2   https://hh.ru/vacancy/33812932
# 3   https://hh.ru/vacancy/32697772
# 4   https://hh.ru/vacancy/33897746
# 5   https://hh.ru/vacancy/33483197
# 6   https://hh.ru/vacancy/34099140
# 7   https://hh.ru/vacancy/33897090
# 8   https://hh.ru/vacancy/34169648
# 9   https://hh.ru/vacancy/34202529
# 10  https://hh.ru/vacancy/33743555
# 11  https://hh.ru/vacancy/33838185
# 12  https://hh.ru/vacancy/34200617
# 13  https://hh.ru/vacancy/34160544
# 14  https://hh.ru/vacancy/31533142
# 15  https://hh.ru/vacancy/34194327
# 16  https://hh.ru/vacancy/34104578
# 17  https://hh.ru/vacancy/33910347
# 18  https://hh.ru/vacancy/33814609
# 19  https://hh.ru/vacancy/34083309
# 20  https://hh.ru/vacancy/34170156
# 21  https://hh.ru/vacancy/34166629
# 22  https://hh.ru/vacancy/34103899
# 23  https://hh.ru/vacancy/33940799
# 24  https://hh.ru/vacancy/33744101
# 25  https://hh.ru/vacancy/33737957
# 26  https://hh.ru/vacancy/34167697
# 27  https://hh.ru/vacancy/34050005
# 28  https://hh.ru/vacancy/34083306
# 29  https://hh.ru/vacancy/33782794
# 30  https://hh.ru/vacancy/34011537
# 31  https://hh.ru/vacancy/33924627
# 32  https://hh.ru/vacancy/33731037
# 33  https://hh.ru/vacancy/34007418
# 34  https://hh.ru/vacancy/33250171
# 35  https://hh.ru/vacancy/34186789
# 36  https://hh.ru/vacancy/34104691
# 37  https://hh.ru/vacancy/33904458
# 38  https://hh.ru/vacancy/32241387
# 39  https://hh.ru/vacancy/34188845
# 40  https://hh.ru/vacancy/32706935
# 41  https://hh.ru/vacancy/33497430
# 42  https://hh.ru/vacancy/34101611
# 43  https://hh.ru/vacancy/32417827
# 44  https://hh.ru/vacancy/33795867
# 45  https://hh.ru/vacancy/34163217
# 46  https://hh.ru/vacancy/33811671
# 47  https://hh.ru/vacancy/34108035
# 48  https://hh.ru/vacancy/33973777
# 49  https://hh.ru/vacancy/34105603
# 50  https://hh.ru/vacancy/34198397
# 51  https://hh.ru/vacancy/33795207
# 52  https://hh.ru/vacancy/33895815
# 53  https://hh.ru/vacancy/34160300
# 54  https://hh.ru/vacancy/34184990
# 55  https://hh.ru/vacancy/34193068
#
#                                          vacancy_text  \
# 0                                     Программист 1 С
# 1      .NET C# Разработчик / .NET C# Developer Norway
# 2                              Программист в Германию
# 3   Инженер-программист ( front-end developer ) ju...
# 4                             ГИС программист (front)
# 5                                     Программист С++
# 6                          Backend разработчик (.NET)
# 7                              ГИС программист (back)
# 8                                     Программист 1С8
# 9                      Front-end разработчик (Senior)
# 10                                     Программист 1C
# 11                      Программист-разработчик (SQL)
# 12                              Junior программист С#
# 13                               Разработчик C++ (Qt)
# 14                                 Программист-стажер
# 15       Программист - разработчик C# (Junior/Middle)
# 16                              Front-end разработчик
# 17                              Программист-стажер 1С
# 18           Фронтенд разработчик в блокчейн компанию
# 19                                    Программист С++
# 20                              Разработчик Front-end
# 21                                        Программист
# 22                                 Программист Delphi
# 23  Angular Фронт-Энд Разработчик / Angular Front-...
# 24                            ASP.NET Developer (MVC)
# 25                                    Программист С++
# 26                            Программист-разработчик
# 27                                        Программист
# 28                                     Программист С#
# 29                                 Программист-стажер
# 30            Fullstack программист (PHP, JavaScript)
# 31  Инженер-разработчик (программист микроконтролл...
# 32                                     Программист С#
# 33                             Инженер-разработчик C#
# 34                                        Программист
# 35                         Backend разработчик (.NET)
# 36                             Начинающий программист
# 37                                    Web-программист
# 38                                    Программист C++
# 39                            Программист 1С (КА 1.1)
# 40                                     Программист С#
# 41                         Fullstack Программист (С#)
# 42            Специалист отдела снабжения/программист
# 43                                    Программист С++
# 44                                        Программист
# 45                                     Программист 1С
# 46                                    Web-программист
# 47                                    Программист IOS
# 48     Прикладной программист (Front-end программист)
# 49                             Младший разработчик C#
# 50                                 Программист Python
# 51                                 Программист 1C 8.3
# 52                  Front-end React/Angular Developer
# 53                              Front-End разработчик
# 54                         Инженер-программист АСУ ТП
# 55                            Программист 1С (Junior)
#
#                                       vacancy_company  \
# 0                          Энергосистемы и Технологии
# 1                                        ООО PaleBlue
# 2                    ИП Сметанин Владимир Анатольевич
# 3    Институт прикладных экономических исследовани...
# 4                                       РеИнформ Инт.
# 5                                               ЮРИОН
# 6                              АйТи Гео, ООО (IT GEO)
# 7                                       РеИнформ Инт.
# 8                                              Вартон
# 9                                            Foundook
# 10                                    ООО ФК БАЛТИМОР
# 11                      Business Solutions Consulting
# 12                                           АРМО, ГК
# 13                                ООО Новотранс Актив
# 14                           Авиком Бизнес Технологии
# 15                                           TEZ TOUR
# 16                              ООО Кредитные Системы
# 17                               ООО Инокспоинт Групп
# 18                                       Endpass, Inc
# 19                                         ОАО НИИТКД
# 20                                   ООО Катюша Ай Ти
# 21                                        ЗАО ТЕРМИКА
# 22                            АО МЦ-Сервис Инжиниринг
# 23                                       ООО PaleBlue
# 24                                          Элемент 5
# 25                          Эверис, Представительство
# 26                                 ООО Софтлоджик Рус
# 27                               ООО Эксид Консалтинг
# 28                                         ОАО НИИТКД
# 29                                      ALEXROVICH.RU
# 30                                       Мир Магнитов
# 31                                  ООО Парус электро
# 32                                          ООО ВЕКАС
# 33                                             Detego
# 34                                                169
# 35                          Эверис, Представительство
# 36                                           Си-Эн-Эс
# 37                             Нияма, Сеть ресторанов
# 38                                          ООО ИНИТИ
# 39                                   ООО Комплекс-Бар
# 40                                           ЕТС груп
# 41                                           1001 Тур
# 42                                        АО Дедал-НВ
# 43                              Группа Компаний «АМЕ»
# 44                                      ЗАО МИРРА - М
# 45                                        ЗАО ЛИНДЕКС
# 46                                   ООО Точка Оплаты
# 47                              ПО Арочные технологии
# 48                                           AERODISK
# 49                                             Кворум
# 50                             Insilico Medicine, Inc
# 51        Алмаз-Антей управленческое консультирование
# 52                                            Soshace
# 53                            ООО Когнитивные системы
# 54                                    DSS Engineering
# 55                                    ООО РусВент МСК
#
#                      vacancy_place  salary_from  salary_to    website
# 0         Москва, Люблино и еще 1      120000.0   140000.0  www.hh.ru
# 1                           Москва     200000.0   300000.0  www.hh.ru
# 2                           Москва       2800.0     3800.0  www.hh.ru
# 3             Москва, Юго-Западная     100000.0   140000.0  www.hh.ru
# 4                           Москва     140000.0        NaN  www.hh.ru
# 5                           Москва      90000.0   110000.0  www.hh.ru
# 6               Москва, Бауманская     150000.0   170000.0  www.hh.ru
# 7                           Москва     140000.0        NaN  www.hh.ru
# 8               Москва, Кунцевская     100000.0        NaN  www.hh.ru
# 9                           Москва          NaN   250000.0  www.hh.ru
# 10              Москва, Бауманская      80000.0    80000.0  www.hh.ru
# 11              Москва, Павелецкая          NaN   120000.0  www.hh.ru
# 12                  Москва, Динамо      55000.0    70000.0  www.hh.ru
# 13                          Москва     200000.0   230000.0  www.hh.ru
# 14                          Москва          NaN        NaN  www.hh.ru
# 15                          Москва      60000.0   100000.0  www.hh.ru
# 16            Москва, Авиамоторная      80000.0   150000.0  www.hh.ru
# 17   Москва, Марксистская и еще 3       30000.0    40000.0  www.hh.ru
# 18                          Москва     120000.0   180000.0  www.hh.ru
# 19                          Москва          NaN   200000.0  www.hh.ru
# 20      Москва, Владыкино и еще 2      170000.0        NaN  www.hh.ru
# 21      Москва, Ленинский проспект          NaN        NaN  www.hh.ru
# 22                          Москва     110000.0   130000.0  www.hh.ru
# 23                          Москва     200000.0   300000.0  www.hh.ru
# 24                   Москва, Южная     130000.0        NaN  www.hh.ru
# 25                          Москва     120000.0        NaN  www.hh.ru
# 26               Москва, Технопарк      70000.0   100000.0  www.hh.ru
# 27                          Москва     150000.0        NaN  www.hh.ru
# 28                          Москва          NaN   200000.0  www.hh.ru
# 29                          Москва      52000.0        NaN  www.hh.ru
# 30                          Москва     100000.0   130000.0  www.hh.ru
# 31                Москва, Царицыно     100000.0        NaN  www.hh.ru
# 32             Москва, Семеновская     100000.0   150000.0  www.hh.ru
# 33           Москва, Новокузнецкая     150000.0   180000.0  www.hh.ru
# 34                          Москва      80000.0        NaN  www.hh.ru
# 35   Москва, Серпуховская и еще 2      150000.0   260000.0  www.hh.ru
# 36              Москва, Бутырская       25000.0    45000.0  www.hh.ru
# 37                          Москва     110000.0        NaN  www.hh.ru
# 38            Москва, Серпуховская     160000.0        NaN  www.hh.ru
# 39            Москва, Алексеевская     150000.0   150000.0  www.hh.ru
# 40  Москва, Улица Академика Янгеля      80000.0   120000.0  www.hh.ru
# 41             Москва, Савеловская          NaN   140000.0  www.hh.ru
# 42                          Москва      30000.0    40000.0  www.hh.ru
# 43             Москва, Теплый Стан          NaN   100000.0  www.hh.ru
# 44              Москва, Бауманская      60000.0    80000.0  www.hh.ru
# 45    Москва, Кожуховская и еще 2      100000.0   150000.0  www.hh.ru
# 46                          Москва      90000.0   150000.0  www.hh.ru
# 47                          Москва      80000.0   100000.0  www.hh.ru
# 48               Москва, Калужская     100000.0   150000.0  www.hh.ru
# 49                          Москва      40000.0    60000.0  www.hh.ru
# 50                          Москва     100000.0   180000.0  www.hh.ru
# 51                    Москва, ВДНХ      70000.0   160000.0  www.hh.ru
# 52                          Москва     200000.0   300000.0  www.hh.ru
# 53                          Москва      80000.0   120000.0  www.hh.ru
# 54           Москва, Академическая      60000.0    90000.0  www.hh.ru
# 55                          Москва      70000.0    80000.0  www.hh.ru
