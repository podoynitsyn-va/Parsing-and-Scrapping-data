# %%
from bs4 import BeautifulSoup as bs
import requests
import re
import pandas as pd

# %%
def determine_salary(salary_string):
    '''
    На вход подаётся строка зарплаты вида:
    "от 10 до 50"
    "от 10"
    "до 50"
    "по договоренности"
    '''
    
    # salary =re.split(r'[^\d+\s+]+', salary_string)
    answer = {'salary_from': None, 'salary_to': None}

    # определим числа, которые содержатся в строке зарплаты
    salary = re.findall(r'[0-9\s]+', salary_string)
    # уберём html-неразрывный пробел между разрядами числа
    salary = [s.replace('\xa0', '') for s in salary]

    '''
    Если в salary 2 элемента, то в качестве начала и окончания вилки берем salary[0] и salary[1].
    Если в salary 1 элемент, то если строка salary_string начинается с 'от',
    то в качестве начала вилки используем salary[0].
    А если в строке salary_string присутствует слово 'до',
    то в качестве окончания вилки используем salary[0].
    Если же salary не содержит числовых элементов, то записываем None в начало и конец вилки
    '''
    if len(salary) == 2:
        answer['salary_from'] = int(salary[0])
        answer['salary_to'] = int(salary[1])
    elif salary_string.split()[0] == 'от':
        answer['salary_from'] = int(salary[0])
    elif salary_string.split().count('до') == 1:
        answer['salary_to'] = int(salary[0])

    return answer

# %%
def get_superjob_data(keyword, link):
    
    link_origin = 'https://www.superjob.ru'
    html = requests.get(link).text
    parsed_html = bs(html, 'html.parser')

    vacancy_list = parsed_html.findAll('div', {'class': 'f-test-vacancy-item'})
    
    #определим ссылку на следующую страницу. Это ссылка на кнопку "Далее"
    next_link = link_origin + parsed_html.find('a',{'rel':'next'})['href']
    
    #создадим списки с данными, которые будем использовать в качестве столбцов датафрейма
    list_vacancy_link = []
    list_vacancy_text = []
    list_vacancy_company = []
    list_vacancy_place = []
    list_salary_from = []
    list_salary_to = []
    
    for vacancy in vacancy_list:
        # ищем дочерние элементы вакансии
        vacancy_info = vacancy.find('div', {'class': '_2g1F-'}).findChild()

        # помимо ссылок на вакансии могут быть ещё и ссылки спонсоров. Надо их отфильтровать
        get_link = re.search('.*vakansii.*', vacancy_info.find('a')['href'])

        # определяем вакансию только если ссылка действительно на вакансию
        if get_link is not None:
            vacancy_link = link_origin + re.search('.*vakansii.*', vacancy_info.find('a')['href']).group(0)
            vacancy_text = vacancy_info.find('a').find('div').getText()
            try:
                vacancy_firm = vacancy_info.find('a', {'target': '_self'}).getText()
            except:
                vacancy_firm = None

            # местонахождение - последний элемент массива
            place = vacancy_info.find('span', {'class': 'f-test-text-company-item-location'}).getText().split()[-1]

            # получим всю строку, отвечающую за зарплату
            salary = vacancy_info.find('span', {'class': 'f-test-text-company-item-salary'}).getText()
            
            salary_dict = determine_salary(salary.strip())
            
            #добавим полученные данные в списки
            list_vacancy_link.append(vacancy_link)
            list_vacancy_text.append(vacancy_text)
            list_vacancy_company.append(vacancy_firm)
            list_vacancy_place.append(place)
            list_salary_from.append(salary_dict['salary_from'])
            list_salary_to.append(salary_dict['salary_to'])      
    
    #загрузим списки в датафрейм
    vacancy_info = pd.DataFrame({'vacancy_link':list_vacancy_link,
                             'vacancy_text':list_vacancy_text,
                             'vacancy_company':list_vacancy_company,
                             'vacancy_place':list_vacancy_place,
                             'salary_from':list_salary_from,
                             'salary_to':list_salary_to})
    return_data = {'data':vacancy_info, 'next_link':next_link}
    return return_data

# %%
keyword = input('Введите ключевое слово, по которому будет выполняться поиск подходящих вакансий:  ')
n_pages = int(input('Введите количество страниц поиска:  '))


page = 1

#основной датафрейм vacancy_list - к нему будем присоединять результаты обхода страниц
vacancy_list = pd.DataFrame({'vacancy_link':[],
                             'vacancy_text':[],
                             'vacancy_company':[],
                             'vacancy_place':[],
                             'salary_from':[],
                             'salary_to':[]})
#ссылка на первую страницу
#Пришлось использовать параметр geo для обхода автоподстановки местоположения
link_superjob = f'https://www.superjob.ru/vacancy/search/?keywords={keyword}&geo%5Bc%5D%5B0%5D=1'

while page <= n_pages:
    data = get_superjob_data(keyword, link_superjob)
    vacancy_info = data['data']
    
    #на следующем шаге цикла вместо первоначальной ссылки используем ссылку на следующую страницу
    link_superjob = data['next_link']
    
    #добавляем полученные данные к vacancy_list
    vacancy_list = pd.concat([vacancy_list,vacancy_info], axis=0, ignore_index=True)
    page +=1
    
vacancy_list['website'] = 'www.superjob.ru'
vacancy_list
# Out:
# Введите ключевое слово, по которому будет выполняться поиск подходящих вакансий:  Программист
# Введите количество страниц поиска:  5
#                                          vacancy_link  \
# 0   https://www.superjob.ru/vakansii/tehnik-progra...
# 1   https://www.superjob.ru/vakansii/programmist-1...
# 2   https://www.superjob.ru/vakansii/programmist-1...
# 3   https://www.superjob.ru/vakansii/programmist-1...
# 4   https://www.superjob.ru/vakansii/programmist-1...
# 5   https://www.superjob.ru/vakansii/programmist-b...
# 6   https://www.superjob.ru/vakansii/programmist-s...
# 7   https://www.superjob.ru/vakansii/programmist-1...
# 8   https://www.superjob.ru/vakansii/veduschij-pro...
# 9   https://www.superjob.ru/vakansii/junior-java-p...
# 10  https://www.superjob.ru/vakansii/veduschij-inz...
# 11  https://www.superjob.ru/vakansii/programmist-1...
# 12  https://www.superjob.ru/vakansii/programmist-3...
# 13  https://www.superjob.ru/vakansii/veduschij-inz...
# 14  https://www.superjob.ru/vakansii/programmist-1...
# 15  https://www.superjob.ru/vakansii/programmist-1...
# 16  https://www.superjob.ru/vakansii/veduschij-pro...
# 17  https://www.superjob.ru/vakansii/php-programmi...
# 18  https://www.superjob.ru/vakansii/programmist-1...
# 19  https://www.superjob.ru/vakansii/programmist-1...
# 20  https://www.superjob.ru/vakansii/programmist-r...
# 21  https://www.superjob.ru/vakansii/programmist-s...
# 22  https://www.superjob.ru/vakansii/programmist-a...
# 23  https://www.superjob.ru/vakansii/programmist-1...
# 24  https://www.superjob.ru/vakansii/programmist-1...
# 25  https://www.superjob.ru/vakansii/programmist-1...
# 26  https://www.superjob.ru/vakansii/veduschij-pro...
# 27  https://www.superjob.ru/vakansii/junior-325217...
# 28  https://www.superjob.ru/vakansii/veduschij-pro...
# 29  https://www.superjob.ru/vakansii/inzhener-prog...
# ..                                                ...
# 40  https://www.superjob.ru/vakansii/programmist-1...
# 41  https://www.superjob.ru/vakansii/programmist-1...
# 42  https://www.superjob.ru/vakansii/inzhener-prog...
# 43  https://www.superjob.ru/vakansii/web-inzhener-...
# 44  https://www.superjob.ru/vakansii/programmist-1...
# 45  https://www.superjob.ru/vakansii/inzhener-prog...
# 46  https://www.superjob.ru/vakansii/inzhener-prog...
# 47  https://www.superjob.ru/vakansii/programmist-1...
# 48  https://www.superjob.ru/vakansii/programmist-1...
# 49  https://www.superjob.ru/vakansii/tehnik-progra...
# 50  https://www.superjob.ru/vakansii/programmist-1...
# 51  https://www.superjob.ru/vakansii/programmist-1...
# 52  https://www.superjob.ru/vakansii/programmist-1...
# 53  https://www.superjob.ru/vakansii/programmist-j...
# 54  https://www.superjob.ru/vakansii/programmist-1...
# 55  https://www.superjob.ru/vakansii/programmist-1...
# 56  https://www.superjob.ru/vakansii/inzhener-prog...
# 57  https://www.superjob.ru/vakansii/programmist-1...
# 58  https://www.superjob.ru/vakansii/programmist-m...
# 59  https://www.superjob.ru/vakansii/programmist-1...
# 60  https://www.superjob.ru/vakansii/programmist-1...
# 61  https://www.superjob.ru/vakansii/programmist-3...
# 62  https://www.superjob.ru/vakansii/programmist-1...
# 63  https://www.superjob.ru/vakansii/programmist-1...
# 64  https://www.superjob.ru/vakansii/programmist-1...
# 65  https://www.superjob.ru/vakansii/programmist-1...
# 66  https://www.superjob.ru/vakansii/veduschij-pro...
# 67  https://www.superjob.ru/vakansii/mladshij-prog...
# 68  https://www.superjob.ru/vakansii/programmist-1...
# 69  https://www.superjob.ru/vakansii/windows-progr...
#
#                                   vacancy_text  \
# 0                           Техник-программист
# 1                               Программист 1С
# 2                               Программист 1С
# 3                               Программист 1С
# 4                               Программист 1С
# 5                       Программист баз данных
# 6                        Программист-стажер 1С
# 7                               Программист 1С
# 8                       Ведущий программист 1С
# 9                      Junior Java-программист
# 10              Ведущий инженер-программист 1С
# 11  Программист 1С в лесопромышленную компанию
# 12                                 Программист
# 13              Ведущий инженер-программист 1С
# 14                              Программист 1С
# 15                              Программист 1С
# 16                  Ведущий программист 1С ERP
# 17                    PHP-программист (Bitrix)
# 18                              Программист 1С
# 19                              Программист 1С
# 20  Программист-разработчик на С/C++ для STM32
# 21                             Программист SQL
# 22                           Программист АСУТП
# 23                          Программист 1С 8.3
# 24                              Программист 1С
# 25                              Программист 1С
# 26                      Ведущий программист 1С
# 27              Junior / MiddlePHP-программист
# 28                      Ведущий программист 1С
# 29                      Инженер-программист 1С
# ..                                         ...
# 40                              Программист 1С
# 41                              Программист 1С
# 42             Инженер-программист 2 категории
# 43              Web-инженер, программист C/C++
# 44                              Программист 1С
# 45             Инженер-программист 3 категории
# 46          Инженер-программист 1, 2 категории
# 47                              Программист 1С
# 48                              Программист 1С
# 49                          Техник-программист
# 50                              Программист 1С
# 51      Программист 1С (начинающий специалист)
# 52             Программист 1С / Разработчик 1С
# 53                            Программист Java
# 54                          Программист 1С 8.3
# 55                              Программист 1С
# 56                         Инженер-программист
# 57                              Программист 1С
# 58               Программист микроконтроллеров
# 59                Программист 1С (тестировщик)
# 60                            Программист 1С 8
# 61                                 Программист
# 62                              Программист 1С
# 63                              Программист 1С
# 64                              Программист 1С
# 65                              Программист 1С
# 66                      Ведущий программист 1С
# 67                     Младший программист PHP
# 68                              Программист 1С
# 69      Windows программист / Разработчик .NET
#
#                                       vacancy_company  \
# 0                            Кадетская школа-интернат
# 1              Аграрная Группа - Управляющая компания
# 2                                           Стаффмикс
# 3                                   "Компания "Сухой"
# 4                    Уфимское хлебообъединение Восход
# 5                                            Мария-РА
# 6                                                 Асф
# 7                                                None
# 8                                       МУП Водоканал
# 9              Управляющая компания Сиб-Транс-Петройл
# 10  Филиал ПАО "Компания "Сухой" "НАЗ им. В. П. Чк...
# 11                                          RFP Group
# 12                                      Бизнес Альянс
# 13                                         Группа ННК
# 14                                               None
# 15                                           НоваДент
# 16                                    Русский Аппетит
# 17                                          Репропарк
# 18                                    Группа компаний
# 19                                           N1 Sport
# 20                                           N1 Sport
# 21                            Группа компаний XXI Век
# 22                                          Стаффмикс
# 23                                         Самсон-опт
# 24                                           ТД "РИФ"
# 25                                         Актив Упак
# 26                                  Компания "Ронова"
# 27                                          Стаффмикс
# 28                                        Инвестстрой
# 29                              Самарский Стройфарфор
# ..                                                ...
# 40                                    УфаМедиаХолдинг
# 41                                         Руссо Упак
# 42                                          Стаффмикс
# 43                                           СДЛ-Софт
# 44                                            МЗАТЭ-2
# 45                                        АБС Электро
# 46                                        АБС Электро
# 47                                    Квадриго сервис
# 48                                ГК "ВИЗАВИ Консалт"
# 49                                              ПКТБА
# 50                         Энергосистемы и Технологии
# 51                                         ГЛОБАЛ ФУД
# 52                                           SUNLIGHT
# 53                                               КРИТ
# 54                                              ПРИМА
# 55                         КОСМИК - парки развлечений
# 56                                               КРИТ
# 57                   "АЭМ-технологии" Филиал "Атоммаш
# 58                                         Интеркросс
# 59                                           Артпласт
# 60         Кадровое агентство уникальных специалистов
# 61                               ГБУЗ "Сегежская ЦРБ"
# 62                                  ПРОДУКТЫ ЕРМОЛИНО
# 63                               Система бронирования
# 64                              Чекотова П.А. Фортуна
# 65                                     Эксклюзив Алко
# 66                                    ПРОМСТРОЙМОНТАЖ
# 67                                         Самсон-опт
# 68                                             Сантим
# 69                                        АйТи Сервис
#
#                        vacancy_place  salary_from  salary_to          website
# 0                     Ханты-Мансийск      35000.0        NaN  www.superjob.ru
# 1                              Томск      70000.0    90000.0  www.superjob.ru
# 2            Санкт-Петербург,Обухово     115000.0        NaN  www.superjob.ru
# 3               Комсомольск-на-Амуре      50000.0        NaN  www.superjob.ru
# 4                                Уфа          NaN        NaN  www.superjob.ru
# 5                            Барнаул      70000.0        NaN  www.superjob.ru
# 6                            Иркутск          NaN        NaN  www.superjob.ru
# 7                            Иркутск          NaN        NaN  www.superjob.ru
# 8                            Иркутск          NaN        NaN  www.superjob.ru
