# %%
from bs4 import BeautifulSoup as bs
import requests
import re
import pandas as pd

def clear_link(link, website):
    '''
    Функция убирает из ссылки лишние параметры,
    несущественные для работы.
    '''
    link = link[:link.find('//')]+'//'+link[link.find(website):link.find('?')]
    return link

def determine_salary(salary_string):
    '''
    Функция выделяет вилку заработной платы
    из строки с размером заработной платы.
    На вход подаётся строка зарплаты вида:
    "от 10 до 50"
    "от 10"
    "до 50"
    "по договоренности"
    '''
    
    # salary =re.split(r'[^\d+\s+]+', salary_string)
    answer = {'salary_from': None, 'salary_to': None}

    # определим числа, которые содержатся в строке зарплаты
    salary = re.findall(r'[0-9\s]+', salary_string)
    # уберём html-неразрывный пробел между разрядами числа
    salary = [s.replace('\xa0', '') for s in salary]

    '''
    Если в salary 2 элемента, то в качестве начала и окончания вилки берем salary[0] и salary[1].
    Если в salary 1 элемент, то если строка salary_string начинается с 'от',
    то в качестве начала вилки используем salary[0].
    А если в строке salary_string присутствует слово 'до',
    то в качестве окончания вилки используем salary[0].
    Если же salary не содержит числовых элементов, то записываем None в начало и конец вилки
    '''
    if len(salary) == 2:
        answer['salary_from'] = int(salary[0])
        answer['salary_to'] = int(salary[1])
    elif salary_string.split()[0] == 'от':
        answer['salary_from'] = int(salary[0])
    elif salary_string.split().count('до') == 1:
        answer['salary_to'] = int(salary[0])
        
    return answer


def get_superjob_data(keyword, link):
    
    link_origin = 'https://www.superjob.ru'
    html = requests.get(link).text
    parsed_html = bs(html, 'html.parser')

    vacancy_list = parsed_html.findAll('div', {'class': 'f-test-vacancy-item'})
    
    #определим ссылку на следующую страницу. Это ссылка на кнопку "Далее"
    next_link = link_origin + parsed_html.find('a',{'rel':'next'})['href']
    
    #создадим списки с данными, которые будем использовать в качестве столбцов датафрейма
    list_vacancy_link = []
    list_vacancy_text = []
    list_vacancy_company = []
    list_vacancy_place = []
    list_salary_from = []
    list_salary_to = []
    
    for vacancy in vacancy_list:
        # ищем дочерние элементы вакансии
        vacancy_info = vacancy.find('div', {'class': '_2g1F-'}).findChild()

        # помимо ссылок на вакансии могут быть ещё и ссылки спонсоров. Надо их отфильтровать
        get_link = re.search('.*vakansii.*', vacancy_info.find('a')['href'])

        # определяем вакансию только если ссылка действительно на вакансию
        if get_link is not None:
            vacancy_link = link_origin + re.search('.*vakansii.*', vacancy_info.find('a')['href']).group(0)
            vacancy_text = vacancy_info.find('a').find('div').getText()
            try:
                vacancy_firm = vacancy_info.find('a', {'target': '_self'}).getText()
            except:
                vacancy_firm = None

            # местонахождение - последний элемент массива
            place = vacancy_info.find('span', {'class': 'f-test-text-company-item-location'}).getText().split()[-1]

            # получим всю строку, отвечающую за зарплату
            salary = vacancy_info.find('span', {'class': 'f-test-text-company-item-salary'}).getText()
            
            salary_dict = determine_salary(salary.strip())
            
            #добавим полученные данные в списки
            list_vacancy_link.append(vacancy_link)
            list_vacancy_text.append(vacancy_text)
            list_vacancy_company.append(vacancy_firm)
            list_vacancy_place.append(place)
            list_salary_from.append(salary_dict['salary_from'])
            list_salary_to.append(salary_dict['salary_to'])      
    
    #загрузим списки в датафрейм
    vacancy_info = pd.DataFrame({'vacancy_link':list_vacancy_link,
                             'vacancy_text':list_vacancy_text,
                             'vacancy_company':list_vacancy_company,
                             'vacancy_place':list_vacancy_place,
                             'salary_from':list_salary_from,
                             'salary_to':list_salary_to})
    
    vacancy_info['website'] = 'www.superjob.ru'
    return_data = {'data':vacancy_info, 'next_link':next_link}
    return return_data


def get_hh_data(keyword, link):
    link_origin = 'https://www.hh.ru'
    headers = {'Accept': '*/*',
               'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:68.0) Gecko/20100101 Firefox/68.0'}
    html = requests.get(link, headers=headers).text
    parsed_html = bs(html, 'html.parser')
    
    vacancy_list = parsed_html.findAll('div', {'data-qa': 'vacancy-serp__vacancy'})

    #определим ссылку на следующую страницу. Это ссылка на кнопку "Далее"
    next_link = link_origin + parsed_html.find('a',{'data-qa':'pager-next'})['href']
    
    #создадим списки с данными, которые будем использовать в качестве столбцов датафрейма
    list_vacancy_link = []
    list_vacancy_text = []
    list_vacancy_company = []
    list_vacancy_place = []
    list_salary_from = []
    list_salary_to = []

    for vacancy in vacancy_list:
        #подчистим ссылку на вакансию
        vacancy_link = clear_link(vacancy.find('a',{'class':'bloko-link'})['href'], 'hh.ru')
        
        vacancy_text = vacancy.find('a',{'class':'bloko-link'}).getText()
        vacancy_firm = vacancy.find('a', {'data-qa': 'vacancy-serp__vacancy-employer'}).getText()
        vacancy_place = vacancy.find('span', {'data-qa': 'vacancy-serp__vacancy-address'}).getText()
        try:
            salary_string = vacancy.find('div', {'class': 'vacancy-serp-item__compensation'}).text
            salary_dict = determine_salary(salary_string)
        except:
            salary_dict = {'salary_from':None, 'salary_to':None}
        
        #добавим полученные данные в списки
        list_vacancy_link.append(vacancy_link)
        list_vacancy_text.append(vacancy_text)
        list_vacancy_company.append(vacancy_firm)
        list_vacancy_place.append(vacancy_place)
        list_salary_from.append(salary_dict['salary_from'])
        list_salary_to.append(salary_dict['salary_to'])      
    
    #загрузим списки в датафрейм
    vacancy_info = pd.DataFrame({'vacancy_link':list_vacancy_link,
                             'vacancy_text':list_vacancy_text,
                             'vacancy_company':list_vacancy_company,
                             'vacancy_place':list_vacancy_place,
                             'salary_from':list_salary_from,
                             'salary_to':list_salary_to})
    
    vacancy_info['website'] = 'www.hh.ru'
    return_data = {'data':vacancy_info, 'next_link':next_link}
    return return_data


#####################################################################################################
#                                    ТЕКСТ ОСНОВНОЙ ПРОГРАММЫ                                       #
#####################################################################################################

keyword = input('Введите ключевое слово, по которому будет выполняться поиск подходящих вакансий:  ')
n_pages = int(input('Введите количество страниц поиска:  '))

#основной датафрейм vacancy_list - к нему будем присоединять результаты обхода страниц
vacancy_list = pd.DataFrame({'vacancy_link':[],
                             'vacancy_text':[],
                             'vacancy_company':[],
                             'vacancy_place':[],
                             'salary_from':[],
                             'salary_to':[]})
#ссылка на первую страницу
#Пришлось использовать параметр geo для обхода автоподстановки местоположения
link_superjob = f'https://www.superjob.ru/vacancy/search/?keywords={keyword}&geo%5Bc%5D%5B0%5D=1'

link_hh = link = f'https://hh.ru/search/vacancy?area=1&st=searchVacancy&text={keyword}'

page = 1
while page <= n_pages:
    
    #Получим данные superjob
    data = get_superjob_data(keyword, link_superjob)
    vacancy_info = data['data']
    
    #на следующем шаге цикла вместо первоначальной ссылки используем ссылку на следующую страницу
    link_superjob = data['next_link']
    
    #добавляем полученные данные к vacancy_list
    vacancy_list = pd.concat([vacancy_list,vacancy_info], axis=0, ignore_index=True, sort = False)
    
    #Получим данные hh
    data = get_hh_data(keyword, link_hh)
    vacancy_info = data['data']
    
    #на следующем шаге цикла вместо первоначальной ссылки используем ссылку на следующую страницу
    link_hh = data['next_link']
    
    #добавляем полученные данные к vacancy_list
    vacancy_list = pd.concat([vacancy_list,vacancy_info], axis=0, ignore_index=True, sort = False)
    
    page +=1
    
vacancy_list.to_csv(f'{keyword}_Vacancy_SJ_HH.csv', encoding='utf-8-sig')    

vacancy_list
# Out:
# Введите ключевое слово, по которому будет выполняться поиск подходящих вакансий:  Швея
# Введите количество страниц поиска:  3
#                                           vacancy_link  \
# 0    https://www.superjob.ru/vakansii/shveya-323078...
# 1    https://www.superjob.ru/vakansii/shveya-322292...
# 2    https://www.superjob.ru/vakansii/shveya-na-pro...
# 3    https://www.superjob.ru/vakansii/shveya-328314...
# 4    https://www.superjob.ru/vakansii/shveya-326365...
# 5    https://www.superjob.ru/vakansii/shveya-portno...
# 6    https://www.superjob.ru/vakansii/shveya-327744...
# 7    https://www.superjob.ru/vakansii/shveya-raskro...
# 8    https://www.superjob.ru/vakansii/shveya-327079...
# 9    https://www.superjob.ru/vakansii/shveya-na-pro...
# 10   https://www.superjob.ru/vakansii/shveya-326267...
# 11   https://www.superjob.ru/vakansii/shveya-325858...
# 12   https://www.superjob.ru/vakansii/shveya-na-skl...
# 13   https://www.superjob.ru/vakansii/shveya-299962...
# 14   https://www.superjob.ru/vakansii/shveya-po-pos...
# 15   https://www.superjob.ru/vakansii/shveya-303370...
# 16   https://www.superjob.ru/vakansii/shveya-na-pro...
# 17   https://www.superjob.ru/vakansii/shveya-327571...
# 18   https://www.superjob.ru/vakansii/shveya-322193...
# 19                      https://hh.ru/vacancy/34106395
# 20                      https://hh.ru/vacancy/34105821
# 21                      https://hh.ru/vacancy/33753379
# 22                      https://hh.ru/vacancy/34168994
# 23                      https://hh.ru/vacancy/34194730
# 24                      https://hh.ru/vacancy/34195012
# 25                      https://hh.ru/vacancy/33904440
# 26                      https://hh.ru/vacancy/33746218
# 27                      https://hh.ru/vacancy/34090755
# 28                      https://hh.ru/vacancy/34093836
# 29                      https://hh.ru/vacancy/33844950
# ..                                                 ...
# 77   https://www.superjob.ru/vakansii/shveya-po-pos...
# 78   https://www.superjob.ru/vakansii/shveya-po-rem...
# 79   https://www.superjob.ru/vakansii/shveya-325904...
# 80   https://www.superjob.ru/vakansii/shveya-na-pro...
# 81   https://www.superjob.ru/vakansii/sborschik-ver...
# 82   https://www.superjob.ru/vakansii/shveya-294612...
# 83   https://www.superjob.ru/vakansii/shveya-v-trik...
# 84   https://www.superjob.ru/vakansii/shveya-na-pro...
# 85   https://www.superjob.ru/vakansii/shveya-na-pro...
# 86   https://www.superjob.ru/vakansii/uchenik-shvei...
# 87                      https://hh.ru/vacancy/33797642
# 88                      https://hh.ru/vacancy/33874937
# 89                      https://hh.ru/vacancy/33716268
# 90                      https://hh.ru/vacancy/34070987
# 91                      https://hh.ru/vacancy/34128718
# 92                      https://hh.ru/vacancy/33880278
# 93                      https://hh.ru/vacancy/34017481
# 94                      https://hh.ru/vacancy/34183338
# 95                      https://hh.ru/vacancy/33722555
# 96                      https://hh.ru/vacancy/34172610
# 97                      https://hh.ru/vacancy/33238723
# 98                      https://hh.ru/vacancy/33481667
# 99                      https://hh.ru/vacancy/33711541
# 100                     https://hh.ru/vacancy/34171941
# 101                     https://hh.ru/vacancy/33247802
# 102                     https://hh.ru/vacancy/33712617
# 103                     https://hh.ru/vacancy/34062455
# 104                     https://hh.ru/vacancy/34053621
# 105                     https://hh.ru/vacancy/33941738
# 106                     https://hh.ru/vacancy/34021554
#
#                                           vacancy_text  \
# 0                                                 Швея
# 1                                                 Швея
# 2                                 Швея на производство
# 3                                      Швея, закройщик
# 4                                                 Швея
# 5                                         Швея-портной
# 6                                 Швея, швея-универсал
# 7                                     Швея-раскройщица
# 8                                                 Швея
# 9                                 Швея на производство
# 10                                                Швея
# 11                        Швея (спецодежда / униформа)
# 12        Швея на склад (вахта с проживанием в Москве)
# 13                                                Швея
# 14                         Швея по пошиву изделий кожи
# 15                                                Швея
# 16                                Швея на производство
# 17                                        Швея (поток)
# 18                                                Швея
# 19                                                Швея
# 20                                                Швея
# 21                                                Швея
# 22                                                Швея
# 23                                                Швея
# 24                                                Швея
# 25                                                Швея
# 26                                                Швея
# 27                                                Швея
# 28                                                Швея
# 29                              Швея/портной-универсал
# ..                                                 ...
# 77                                 Швея по пошиву штор
# 78                          Швея по ремонту спецодежды
# 79                                                Швея
# 80                                Швея на производство
# 81                          Сборщик верха обуви (швея)
# 82                                                Швея
# 83                              Швея в трикотажный цех
# 84                                Швея на производство
# 85                  Швея на производство нижнего белья
# 86                                         Ученик швеи
# 87                                        Швея-портной
# 88                  Швея (Ремонт и реставрация одежды)
# 89                                        Швея-портной
# 90                             Швея-лаборант универсал
# 91                                 Швея по пошиву штор
# 92    Швея (ремонт и подгон по размеру элитной одежды)
# 93   Швея на поточное производство / швея / швея-по...
# 94                                        Швея-портной
# 95                      Швея на мебельное производство
# 96                              Швея по ремонту одежды
# 97                               Швея-портной в Ателье
# 98                                       Швея на поток
# 99                                      Швея / портной
# 100                                       Швея-портной
# 101                                       Швея-портной
# 102                   Швея (шторы, покрывала, подушки)
# 103                              Швея-Портной в ателье
# 104                 Швея на производство мягкой мебели
# 105                Администратор ателье/швея-приемщица
# 106                                    Швея - лаборант
#
#                        vacancy_company                   vacancy_place  \
# 0                          Авторадости                           Пенза
# 1                         Кабаре Салун                       Хабаровск
# 2                         Классик Плюс                          Самара
# 3                        Эдем текстиль        Петропавловск-Камчатский
# 4                                 Ника                            Клин
# 5                             BUTTON'S                     Симферополь
# 6                            Стаффмикс     Санкт-Петербург,Электросила
# 7                     Герасимова Т. Л.                         Обнинск
# 8                   Дом тканей Колибри                         Иркутск
# 9                            Кофтёныши        Санкт-Петербург,Нарвская
# 10                           Стаффмикс            Новгород,Буревестник
# 11                        Фабрика ТРУД                         Ступино
# 12                  Master-Staff Group                       Дмитровск
# 13                                 ЦОБ      Санкт-Петербург,Балтийская
# 14                            Вайнтриб                 Санкт-Петербург
# 15                            СУШИ WOK                 Санкт-Петербург
# 16                            Др. ДЕКО                         станция
# 17                              Обанзе         Москва,Электрозаводская
# 18                           БТК групп                      Всеволожск
# 19                          ООО РПК ОМ                          Москва
# 20                               РИОНА                          Москва
# 21                           MARY MARY                          Москва
# 22                     ООО Профиль Мск    Москва, Шипиловская и еще 2
# 23                           ООО Текса                          Москва
# 24                     ООО Цивилизация                          Москва
# 25                   ООО Фабрика Кухня  Москва, Речной вокзал и еще 1
# 26                            Bornsoon               Москва, Тропарево
# 27            ООО АТЕЛЬЕРИЯ техноложис     Москва, Смоленская и еще 2
# 28                    ООО Консул Медиа                          Москва
# 29    Салон-ателье Royal Dance Couture                          Москва
# ..                                 ...                             ...
# 77                                 Фея                          Казань
# 78        Группа компаний Blesk InCare                          Тамбов
# 79                        Русская кожа                          Рязань
# 80                         Мэджик Сити                         Королев
# 81                       Скороход-Мода                          Ворота
# 82                      Текстиль Групп                      Балтийская
# 83        Крупная текстильная компания                         Иваново
# 84                            Marymary                 Москва,Тульская
# 85                              Брашоп                          Москва
# 86                          КурскОбувь                           Курск
# 87                  ООО Детская одежда       Москва, Хорошево и еще 1
# 88                    ООО Мультимастер                          Москва
# 89                      ООО Ирма-Декор                          Москва
# 90        ИП Назарова Елена Викторовна                          Москва
# 91                  ИП Селифонова И.Н.                          Москва
# 92                    ООО Мультимастер                          Москва
# 93                       ИванычЪ GROUP  Москва, Преображенская площадь
# 94                         Morozovanna              Москва, Павелецкая
# 95                         АпартМебель          Москва, Новохохловская
# 96                     Ателье Светлана                          Москва
# 97                    Galaanna atelier                          Москва
# 98                          FINN FLARE     Москва, Варшавская и еще 1
# 99                     СУДАРЬ, Магазин                          Москва
# 100            ООО Интерьерные решения          Москва, Соколиная Гора
# 101                         FINN FLARE     Москва, Варшавская и еще 1
# 102     ИП Бродовская Наталия Петровна                   Москва, Южная
# 103                       Moya-krasota                          Москва
# 104                 CAZARINA INTERIORS  Москва, Волгоградский проспект
# 105                        Ателье Dial                          Москва
# 106                      ООО Паола Рэй                          Москва
#
#      salary_from  salary_to          website
# 0        23000.0    38000.0  www.superjob.ru
# 1            NaN        NaN  www.superjob.ru
# 2            NaN        NaN  www.superjob.ru
# 3        30000.0    45000.0  www.superjob.ru
# 4        40000.0        NaN  www.superjob.ru
# 5        28000.0    60000.0  www.superjob.ru
# 6        35000.0        NaN  www.superjob.ru
# 7        35000.0        NaN  www.superjob.ru
# 8        30000.0        NaN  www.superjob.ru
# 9        45000.0    65000.0  www.superjob.ru
# 10       30000.0        NaN  www.superjob.ru
# 11       20000.0        NaN  www.superjob.ru
# 12       60000.0        NaN  www.superjob.ru
# 13           NaN        NaN  www.superjob.ru
# 14       30000.0    70000.0  www.superjob.ru
# 15       30000.0        NaN  www.superjob.ru
# 16       40000.0        NaN  www.superjob.ru
# 17           NaN        NaN  www.superjob.ru
# 18       30000.0        NaN  www.superjob.ru
# 19       40000.0        NaN        www.hh.ru
# 20       40000.0        NaN        www.hh.ru
# 21       50000.0    60000.0        www.hh.ru
# 22           NaN    40000.0        www.hh.ru
# 23           NaN        NaN        www.hh.ru
# 24       40000.0    50000.0        www.hh.ru
# 25       55000.0        NaN        www.hh.ru
# 26       40000.0        NaN        www.hh.ru
# 27       50000.0        NaN        www.hh.ru
# 28       35000.0    70000.0        www.hh.ru
# 29       50000.0   100000.0        www.hh.ru
# ..           ...        ...              ...
# 77           NaN        NaN  www.superjob.ru
# 78       12000.0        NaN  www.superjob.ru
# 79       28000.0        NaN  www.superjob.ru
# 80       30000.0    60000.0  www.superjob.ru
# 81       30000.0    70000.0  www.superjob.ru
# 82           NaN        NaN  www.superjob.ru
# 83       40000.0        NaN  www.superjob.ru
# 84       50000.0        NaN  www.superjob.ru
# 85       60000.0        NaN  www.superjob.ru
# 86       17000.0        NaN  www.superjob.ru
# 87       50000.0    80000.0        www.hh.ru
# 88       60000.0        NaN        www.hh.ru
# 89       35000.0    80000.0        www.hh.ru
# 90       40000.0    50000.0        www.hh.ru
# 91       40000.0    55000.0        www.hh.ru
# 92       70000.0        NaN        www.hh.ru
# 93       50000.0    70000.0        www.hh.ru
# 94       60000.0        NaN        www.hh.ru
# 95       40000.0    60000.0        www.hh.ru
# 96       60000.0    80000.0        www.hh.ru
# 97       60000.0   110000.0        www.hh.ru
# 98       34400.0    48000.0        www.hh.ru
# 99       37000.0        NaN        www.hh.ru
# 100      60000.0   100000.0        www.hh.ru
# 101      40500.0    40500.0        www.hh.ru
# 102      40000.0    60000.0        www.hh.ru
# 103      30000.0    40000.0        www.hh.ru
# 104      50000.0    70000.0        www.hh.ru
# 105      35000.0    50000.0        www.hh.ru
# 106      45000.0    50000.0        www.hh.ru
#
# [107 rows x 7 columns]
