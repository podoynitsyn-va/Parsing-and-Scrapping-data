# %%
from bs4 import BeautifulSoup as bs
import requests
import re
import pandas as pd

def clear_link(link, website):
    link = link[:link.find('//')]+'//'+link[link.find(website):link.find('?')]
    return link

def determine_salary(salary_string):
    '''
    На вход подаётся строка зарплаты вида:
    "от 10 до 50"
    "от 10"
    "до 50"
    "по договоренности"
    '''
    
    # salary =re.split(r'[^\d+\s+]+', salary_string)
    answer = {'salary_from': None, 'salary_to': None}

    # определим числа, которые содержатся в строке зарплаты
    salary = re.findall(r'[0-9\s]+', salary_string)
    # уберём html-неразрывный пробел между разрядами числа
    salary = [s.replace('\xa0', '') for s in salary]

    '''
    Если в salary 2 элемента, то в качестве начала и окончания вилки берем salary[0] и salary[1].
    Если в salary 1 элемент, то если строка salary_string начинается с 'от',
    то в качестве начала вилки используем salary[0].
    А если в строке salary_string присутствует слово 'до',
    то в качестве окончания вилки используем salary[0].
    Если же salary не содержит числовых элементов, то записываем None в начало и конец вилки
    '''
    if len(salary) == 2:
        answer['salary_from'] = int(salary[0])
        answer['salary_to'] = int(salary[1])
    elif salary_string.split()[0] == 'от':
        answer['salary_from'] = int(salary[0])
    elif salary_string.split().count('до') == 1:
        answer['salary_to'] = int(salary[0])
        
    return answer


def get_superjob_data(keyword, link):
    
    link_origin = 'https://www.superjob.ru'
    html = requests.get(link).text
    parsed_html = bs(html, 'html.parser')

    vacancy_list = parsed_html.findAll('div', {'class': 'f-test-vacancy-item'})
    
    #определим ссылку на следующую страницу. Это ссылка на кнопку "Далее"
    next_link = link_origin + parsed_html.find('a',{'rel':'next'})['href']
    
    #создадим списки с данными, которые будем использовать в качестве столбцов датафрейма
    list_vacancy_link = []
    list_vacancy_text = []
    list_vacancy_company = []
    list_vacancy_place = []
    list_salary_from = []
    list_salary_to = []
    
    for vacancy in vacancy_list:
        # ищем дочерние элементы вакансии
        vacancy_info = vacancy.find('div', {'class': '_2g1F-'}).findChild()

        # помимо ссылок на вакансии могут быть ещё и ссылки спонсоров. Надо их отфильтровать
        get_link = re.search('.*vakansii.*', vacancy_info.find('a')['href'])

        # определяем вакансию только если ссылка действительно на вакансию
        if get_link is not None:
            vacancy_link = link_origin + re.search('.*vakansii.*', vacancy_info.find('a')['href']).group(0)
            vacancy_text = vacancy_info.find('a').find('div').getText()
            try:
                vacancy_firm = vacancy_info.find('a', {'target': '_self'}).getText()
            except:
                vacancy_firm = None

            # местонахождение - последний элемент массива
            place = vacancy_info.find('span', {'class': 'f-test-text-company-item-location'}).getText().split()[-1]

            # получим всю строку, отвечающую за зарплату
            salary = vacancy_info.find('span', {'class': 'f-test-text-company-item-salary'}).getText()
            
            salary_dict = determine_salary(salary.strip())
            
            #добавим полученные данные в списки
            list_vacancy_link.append(vacancy_link)
            list_vacancy_text.append(vacancy_text)
            list_vacancy_company.append(vacancy_firm)
            list_vacancy_place.append(place)
            list_salary_from.append(salary_dict['salary_from'])
            list_salary_to.append(salary_dict['salary_to'])      
    
    #загрузим списки в датафрейм
    vacancy_info = pd.DataFrame({'vacancy_link':list_vacancy_link,
                             'vacancy_text':list_vacancy_text,
                             'vacancy_company':list_vacancy_company,
                             'vacancy_place':list_vacancy_place,
                             'salary_from':list_salary_from,
                             'salary_to':list_salary_to})
    
    vacancy_info['website'] = 'www.superjob.ru'
    return_data = {'data':vacancy_info, 'next_link':next_link}
    return return_data


def get_hh_data(keyword, link):
    link_origin = 'https://www.hh.ru'
    headers = {'Accept': '*/*',
               'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:68.0) Gecko/20100101 Firefox/68.0'}
    html = requests.get(link, headers=headers).text
    parsed_html = bs(html, 'html.parser')
    
    vacancy_list = parsed_html.findAll('div', {'data-qa': 'vacancy-serp__vacancy'})

    #определим ссылку на следующую страницу. Это ссылка на кнопку "Далее"
    next_link = link_origin + parsed_html.find('a',{'data-qa':'pager-next'})['href']
    
    #создадим списки с данными, которые будем использовать в качестве столбцов датафрейма
    list_vacancy_link = []
    list_vacancy_text = []
    list_vacancy_company = []
    list_vacancy_place = []
    list_salary_from = []
    list_salary_to = []

    for vacancy in vacancy_list:
        #подчистим ссылку на вакансию
        vacancy_link = clear_link(vacancy.find('a',{'class':'bloko-link'})['href'], 'hh.ru')
        
        vacancy_text = vacancy.find('a',{'class':'bloko-link'}).getText()
        vacancy_firm = vacancy.find('a', {'data-qa': 'vacancy-serp__vacancy-employer'}).getText()
        vacancy_place = vacancy.find('span', {'data-qa': 'vacancy-serp__vacancy-address'}).getText()
        try:
            salary_string = vacancy.find('div', {'class': 'vacancy-serp-item__compensation'}).text
            salary_dict = determine_salary(salary_string)
        except:
            salary_dict = {'salary_from':None, 'salary_to':None}
        
        #добавим полученные данные в списки
        list_vacancy_link.append(vacancy_link)
        list_vacancy_text.append(vacancy_text)
        list_vacancy_company.append(vacancy_firm)
        list_vacancy_place.append(vacancy_place)
        list_salary_from.append(salary_dict['salary_from'])
        list_salary_to.append(salary_dict['salary_to'])      
    
    #загрузим списки в датафрейм
    vacancy_info = pd.DataFrame({'vacancy_link':list_vacancy_link,
                             'vacancy_text':list_vacancy_text,
                             'vacancy_company':list_vacancy_company,
                             'vacancy_place':list_vacancy_place,
                             'salary_from':list_salary_from,
                             'salary_to':list_salary_to})
    
    vacancy_info['website'] = 'www.hh.ru'
    return_data = {'data':vacancy_info, 'next_link':next_link}
    return return_data


#####################################################################################################
#                                    ТЕКСТ ОСНОВНОЙ ПРОГРАММЫ                                       #
#####################################################################################################

keyword = input('Введите ключевое слово, по которому будет выполняться поиск подходящих вакансий:  ')
n_pages = int(input('Введите количество страниц поиска:  '))

#основной датафрейм vacancy_list - к нему будем присоединять результаты обхода страниц
vacancy_list = pd.DataFrame({'vacancy_link':[],
                             'vacancy_text':[],
                             'vacancy_company':[],
                             'vacancy_place':[],
                             'salary_from':[],
                             'salary_to':[]})
#ссылка на первую страницу
#Пришлось использовать параметр geo для обхода автоподстановки местоположения
link_superjob = f'https://www.superjob.ru/vacancy/search/?keywords={keyword}&geo%5Bc%5D%5B0%5D=1'

link_hh = link = f'https://hh.ru/search/vacancy?area=1&st=searchVacancy&text={keyword}'

page = 1
while page <= n_pages:
    
    #Получим данные superjob
    data = get_superjob_data(keyword, link_superjob)
    vacancy_info = data['data']
    
    #на следующем шаге цикла вместо первоначальной ссылки используем ссылку на следующую страницу
    link_superjob = data['next_link']
    
    #добавляем полученные данные к vacancy_list
    vacancy_list = pd.concat([vacancy_list,vacancy_info], axis=0, ignore_index=True, sort = False)
    
    #Получим данные hh
    data = get_hh_data(keyword, link_hh)
    vacancy_info = data['data']
    
    #на следующем шаге цикла вместо первоначальной ссылки используем ссылку на следующую страницу
    link_hh = data['next_link']
    
    #добавляем полученные данные к vacancy_list
    vacancy_list = pd.concat([vacancy_list,vacancy_info], axis=0, ignore_index=True, sort = False)
    
    page +=1
    
vacancy_list.to_csv(f'{keyword}_Vacancy_SJ_HH.csv', encoding='utf-8-sig')    

vacancy_list
# Out:
# Введите ключевое слово, по которому будет выполняться поиск подходящих вакансий:  Программист
# Введите количество страниц поиска:  5
#                                           vacancy_link  \
# 0    https://www.superjob.ru/vakansii/pomoschnik-pr...
# 1    https://www.superjob.ru/vakansii/programmist-1...
# 2    https://www.superjob.ru/vakansii/veduschij-pro...
# 3    https://www.superjob.ru/vakansii/programmist-3...
# 4    https://www.superjob.ru/vakansii/veduschij-pro...
# 5    https://www.superjob.ru/vakansii/programmist-1...
# 6    https://www.superjob.ru/vakansii/programmist-1...
# 7    https://www.superjob.ru/vakansii/inzhener-prog...
# 8    https://www.superjob.ru/vakansii/tehnik-progra...
# 9    https://www.superjob.ru/vakansii/programmist-1...
# 10   https://www.superjob.ru/vakansii/programmist-1...
# 11   https://www.superjob.ru/vakansii/programmist-1...
# 12   https://www.superjob.ru/vakansii/programmist-1...
# 13   https://www.superjob.ru/vakansii/programmist-b...
# 14   https://www.superjob.ru/vakansii/programmist-s...
# 15   https://www.superjob.ru/vakansii/programmist-1...
# 16   https://www.superjob.ru/vakansii/veduschij-pro...
# 17   https://www.superjob.ru/vakansii/junior-java-p...
# 18   https://www.superjob.ru/vakansii/veduschij-inz...
# 19   https://www.superjob.ru/vakansii/programmist-1...
# 20   https://www.superjob.ru/vakansii/programmist-3...
# 21   https://www.superjob.ru/vakansii/veduschij-inz...
# 22   https://www.superjob.ru/vakansii/programmist-1...
# 23   https://www.superjob.ru/vakansii/programmist-1...
# 24   https://www.superjob.ru/vakansii/veduschij-pro...
# 25   https://www.superjob.ru/vakansii/php-programmi...
# 26   https://www.superjob.ru/vakansii/programmist-1...
# 27   https://www.superjob.ru/vakansii/programmist-1...
# 28   https://www.superjob.ru/vakansii/programmist-r...
# 29   https://www.superjob.ru/vakansii/programmist-s...
# ..                                                 ...
# 96   https://www.superjob.ru/vakansii/programmist-1...
# 97   https://www.superjob.ru/vakansii/programmist-j...
# 98   https://www.superjob.ru/vakansii/programmist-1...
# 99   https://www.superjob.ru/vakansii/programmist-1...
# 100  https://www.superjob.ru/vakansii/inzhener-prog...
# 101  https://www.superjob.ru/vakansii/programmist-1...
# 102  https://www.superjob.ru/vakansii/programmist-m...
# 103  https://www.superjob.ru/vakansii/programmist-1...
# 104  https://www.superjob.ru/vakansii/programmist-1...
# 105  https://www.superjob.ru/vakansii/programmist-3...
# 106                     https://hh.ru/vacancy/34104691
# 107                     https://hh.ru/vacancy/33904458
# 108                     https://hh.ru/vacancy/32241387
# 109                     https://hh.ru/vacancy/34188845
# 110                     https://hh.ru/vacancy/32706935
# 111                     https://hh.ru/vacancy/33497430
# 112                     https://hh.ru/vacancy/34101611
# 113                     https://hh.ru/vacancy/32417827
# 114                     https://hh.ru/vacancy/33795867
# 115                     https://hh.ru/vacancy/34163217
# 116                     https://hh.ru/vacancy/33811671
# 117                     https://hh.ru/vacancy/34108035
# 118                     https://hh.ru/vacancy/33973777
# 119                     https://hh.ru/vacancy/34105603
# 120                     https://hh.ru/vacancy/34198397
# 121                     https://hh.ru/vacancy/33795207
# 122                     https://hh.ru/vacancy/33895815
# 123                     https://hh.ru/vacancy/34160300
# 124                     https://hh.ru/vacancy/34184990
# 125                     https://hh.ru/vacancy/34193068
#
#                                           vacancy_text  \
# 0                             Помощник программиста 1С
# 1    Программист 1С (Специалист по автоматизации бу...
# 2                              Ведущий программист PHP
# 3    Программист 3 ей категории, программист ABAP, ...
# 4                               Ведущий программист 1С
# 5                                       Программист 1С
# 6                                       Программист 1С
# 7                           Инженер-программист АСУ ТП
# 8                                   Техник-программист
# 9                                       Программист 1С
# 10                                      Программист 1С
# 11                                      Программист 1С
# 12                                      Программист 1С
# 13                              Программист баз данных
# 14                               Программист-стажер 1С
# 15                                      Программист 1С
# 16                              Ведущий программист 1С
# 17                             Junior Java-программист
# 18                      Ведущий инженер-программист 1С
# 19          Программист 1С в лесопромышленную компанию
# 20                                         Программист
# 21                      Ведущий инженер-программист 1С
# 22                                      Программист 1С
# 23                                      Программист 1С
# 24                          Ведущий программист 1С ERP
# 25                            PHP-программист (Bitrix)
# 26                                      Программист 1С
# 27                                      Программист 1С
# 28          Программист-разработчик на С/C++ для STM32
# 29                                     Программист SQL
# ..                                                 ...
# 96                     Программист 1С / Разработчик 1С
# 97                                    Программист Java
# 98                                  Программист 1С 8.3
# 99                                      Программист 1С
# 100                                Инженер-программист
# 101                                     Программист 1С
# 102                      Программист микроконтроллеров
# 103                       Программист 1С (тестировщик)
# 104                                   Программист 1С 8
# 105                                        Программист
# 106                             Начинающий программист
# 107                                    Web-программист
# 108                                    Программист C++
# 109                            Программист 1С (КА 1.1)
# 110                                     Программист С#
# 111                         Fullstack Программист (С#)
# 112            Специалист отдела снабжения/программист
# 113                                    Программист С++
# 114                                        Программист
# 115                                     Программист 1С
# 116                                    Web-программист
# 117                                    Программист IOS
# 118     Прикладной программист (Front-end программист)
# 119                             Младший разработчик C#
# 120                                 Программист Python
# 121                                 Программист 1C 8.3
# 122                  Front-end React/Angular Developer
# 123                              Front-End разработчик
# 124                         Инженер-программист АСУ ТП
# 125                            Программист 1С (Junior)
#
#                                        vacancy_company  \
# 0                                    Бизнес Технолоджи
# 1                              Русская Аграрная Группа
# 2                                           Самсон-опт
# 3                       Иркутский филиал №2 ООО "ОЦРВ"
# 4                Тамерлан Сеть универсамов "Покупочка"
# 5                                        Сады Придонья
# 6                                                 None
# 7                   Судостроительный комплекс "Звезда"
# 8                             Кадетская школа-интернат
# 9               Аграрная Группа - Управляющая компания
# 10                                           Стаффмикс
# 11                                   "Компания "Сухой"
# 12                    Уфимское хлебообъединение Восход
# 13                                            Мария-РА
# 14                                                 Асф
# 15                                                None
# 16                                       МУП Водоканал
# 17              Управляющая компания Сиб-Транс-Петройл
# 18   Филиал ПАО "Компания "Сухой" "НАЗ им. В. П. Чк...
# 19                                           RFP Group
# 20                                       Бизнес Альянс
# 21                                          Группа ННК
# 22                                                None
# 23                                            НоваДент
# 24                                     Русский Аппетит
# 25                                           Репропарк
# 26                                     Группа компаний
# 27                                            N1 Sport
# 28                                            N1 Sport
# 29                             Группа компаний XXI Век
# ..                                                 ...
# 96                                            SUNLIGHT
# 97                                                КРИТ
# 98                                               ПРИМА
# 99                          КОСМИК - парки развлечений
# 100                                               КРИТ
# 101                   "АЭМ-технологии" Филиал "Атоммаш
# 102                                         Интеркросс
# 103                                           Артпласт
# 104         Кадровое агентство уникальных специалистов
# 105                               ГБУЗ "Сегежская ЦРБ"
# 106                                           Си-Эн-Эс
# 107                             Нияма, Сеть ресторанов
# 108                                          ООО ИНИТИ
# 109                                   ООО Комплекс-Бар
# 110                                           ЕТС груп
# 111                                           1001 Тур
# 112                                        АО Дедал-НВ
# 113                              Группа Компаний «АМЕ»
# 114                                      ЗАО МИРРА - М
# 115                                        ЗАО ЛИНДЕКС
# 116                                   ООО Точка Оплаты
# 117                              ПО Арочные технологии
# 118                                           AERODISK
# 119                                             Кворум
# 120                             Insilico Medicine, Inc
# 121        Алмаз-Антей управленческое консультирование
# 122                                            Soshace
# 123                            ООО Когнитивные системы
# 124                                    DSS Engineering
# 125                                    ООО РусВент МСК
#
#                       vacancy_place  salary_from  salary_to          website
# 0                          проспект      17400.0   170000.0  www.superjob.ru
# 1                            Рязань          NaN        NaN  www.superjob.ru
# 2                           Воронеж     120000.0        NaN  www.superjob.ru
# 3                           Иркутск      40000.0    60000.0  www.superjob.ru
# 4                         Волгоград      90000.0   102000.0  www.superjob.ru
# 5                         Волгоград      38700.0    48300.0  www.superjob.ru
# 6                           Саратов          NaN        NaN  www.superjob.ru
# 7                        Красноярск      52000.0        NaN  www.superjob.ru
# 8                    Ханты-Мансийск      35000.0        NaN  www.superjob.ru
# 9                             Томск      70000.0    90000.0  www.superjob.ru
# 10          Санкт-Петербург,Обухово     115000.0        NaN  www.superjob.ru
# 11             Комсомольск-на-Амуре      50000.0        NaN  www.superjob.ru
# 12                              Уфа          NaN        NaN  www.superjob.ru
# 13                          Барнаул      70000.0        NaN  www.superjob.ru
# 14                          Иркутск          NaN        NaN  www.superjob.ru
# 15                          Иркутск          NaN        NaN  www.superjob.ru
# 16                          Иркутск          NaN        NaN  www.superjob.ru
# 17                          Иркутск      35000.0        NaN  www.superjob.ru
# 18                      Новосибирск      70000.0    80000.0  www.superjob.ru
# 19             Комсомольск-на-Амуре      55000.0        NaN  www.superjob.ru
# 20                        Хабаровск          NaN        NaN  www.superjob.ru
# 21                      Владивосток          NaN        NaN  www.superjob.ru
# 22                        Ульяновск      90000.0        NaN  www.superjob.ru
# 23                        Волгоград      25000.0    40000.0  www.superjob.ru
# 24                          Воронеж          NaN        NaN  www.superjob.ru
# 25                           Москва      80000.0        NaN  www.superjob.ru
# 26                            Химки          NaN        NaN  www.superjob.ru
# 27                            Пенза          NaN        NaN  www.superjob.ru
# 28                            Пенза          NaN        NaN  www.superjob.ru
# 29                   Ростов-на-Дону          NaN        NaN  www.superjob.ru
# ..                              ...          ...        ...              ...
# 96                           Москва     150000.0        NaN  www.superjob.ru
# 97                           Ижевск      80000.0        NaN  www.superjob.ru
# 98                   Москва,Ховрино     120000.0   160000.0  www.superjob.ru
# 99                           Москва          NaN        NaN  www.superjob.ru
# 100                          Ижевск      60000.0        NaN  www.superjob.ru
# 101                      Волгодонск          NaN        NaN  www.superjob.ru
# 102                          Рязань      45000.0        NaN  www.superjob.ru
# 103                        Серпухов          NaN        NaN  www.superjob.ru
# 104                          Москва     120000.0        NaN  www.superjob.ru
# 105                          Сегежа      20000.0        NaN  www.superjob.ru
# 106              Москва, Бутырская       25000.0    45000.0        www.hh.ru
# 107                          Москва     110000.0        NaN        www.hh.ru
# 108            Москва, Серпуховская     160000.0        NaN        www.hh.ru
# 109            Москва, Алексеевская     150000.0   150000.0        www.hh.ru
# 110  Москва, Улица Академика Янгеля      80000.0   120000.0        www.hh.ru
# 111             Москва, Савеловская          NaN   140000.0        www.hh.ru
# 112                          Москва      30000.0    40000.0        www.hh.ru
# 113             Москва, Теплый Стан          NaN   100000.0        www.hh.ru
# 114              Москва, Бауманская      60000.0    80000.0        www.hh.ru
# 115    Москва, Кожуховская и еще 2      100000.0   150000.0        www.hh.ru
# 116                          Москва      90000.0   150000.0        www.hh.ru
# 117                          Москва      80000.0   100000.0        www.hh.ru
# 118               Москва, Калужская     100000.0   150000.0        www.hh.ru
# 119                          Москва      40000.0    60000.0        www.hh.ru
# 120                          Москва     100000.0   180000.0        www.hh.ru
# 121                    Москва, ВДНХ      70000.0   160000.0        www.hh.ru
# 122                          Москва     200000.0   300000.0        www.hh.ru
# 123                          Москва      80000.0   120000.0        www.hh.ru
# 124           Москва, Академическая      60000.0    90000.0        www.hh.ru
# 125                          Москва      70000.0    80000.0        www.hh.ru
#
# [126 rows x 7 columns]
